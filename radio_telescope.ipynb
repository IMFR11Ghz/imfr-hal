# %%
import serial
import numpy as np
from matplotlib import pyplot as plt

# %%
ser = serial.Serial('/dev/ttyUSB0', 115200 )

# %%
while True:
    reading = ser.readline()
    print(reading)
# Out:
# b'5.47 0.616750000\r\n'
# b'5.53 0.574000000\r\n'
# b'5.59 0.597000000\r\n'
# b'5.65 0.597875000\r\n'
# b'5.70 0.576375000\r\n'
# b'5.76 0.621125000\r\n'
# b'5.82 0.558375000\r\n'
# b'5.88 0.639750000\r\n'
# b'5.94 0.541250000\r\n'
# b'6.00 0.648750000\r\n'
# b'6.06 0.543875000\r\n'
# b'6.12 0.637875000\r\n'
# b'6.18 0.554375000\r\n'
# b'6.24 0.619750000\r\n'
# b'6.29 0.570250000\r\n'
# b'6.35 0.600000000\r\n'
# b'6.41 0.591875000\r\n'
# b'6.47 0.579750000\r\n'
# b'6.53 0.616750000\r\n'
# b'6.59 0.561000000\r\n'
# b'6.65 0.635500000\r\n'
# b'6.71 0.544125000\r\n'
# b'6.77 0.648875000\r\n'
# b'6.83 0.541375000\r\n'
# b'6.88 0.640500000\r\n'
# b'6.94 0.551250000\r\n'
# b'7.00 0.623625000\r\n'
# b'7.06 0.565750000\r\n'
# b'7.12 0.605750000\r\n'
# b'7.18 0.587000000\r\n'
# b'7.24 0.585000000\r\n'
# b'7.30 0.611875000\r\n'
# b'7.36 0.565000000\r\n'
# b'7.42 0.632000000\r\n'
# b'7.47 0.546375000\r\n'
# b'7.53 0.647500000\r\n'
# b'7.59 0.540875000\r\n'
# b'7.65 0.643375000\r\n'
# ...
